# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = [None] + list(image_shape), name = "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = [None, n_classes], name = "y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name = "keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #forma = list(conv_ksize)+list(x_tensor.shape[2])+[conv_num_outputs]
    
    #print(x_tensor.get_shape().as_list()[1:4])
    #print([conv_num_outputs])
    W = tf.Variable(tf.truncated_normal(list(x_tensor.get_shape().as_list()[1:4])+[conv_num_outputs]))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    #print(W.shape)
    
    conv_layer = tf.nn.conv2d(x_tensor, W, strides=[1]+list(conv_strides)+[1], padding='SAME')
    #print(conv_layer.get_shape())
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    #print(conv_layer.get_shape())
    conv_layer = tf.nn.sigmoid(conv_layer)
    #print(conv_layer.get_shape())
    #print(pool_ksize)
    conv_layer = tf.nn.max_pool(conv_layer, [1] + list(pool_ksize) + [1], [1] + list(pool_strides) + [1], padding = 'SAME')
    #print(conv_layer.get_shape())
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, activation_fn = tf.nn.sigmoid)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, activation_fn = tf.nn.relu)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    net = conv2d_maxpool(x, 15, (2,2), (2,2), (2,2), (2,2))
    net = conv2d_maxpool(net, 15, (2,2), (2,2), (2,2), (1,1))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    net = flatten(net)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    net = fully_conn(net, 30)
    net = fully_conn(net, 20)
    net = fully_conn(net, 20)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    net = output(net, 10)
    
    # TODO: return output
    return net


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    
    valid_acc = session.run(accuracy, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    
    print("\nLoss: {}. Validation Accuracy {} \n".format(loss, valid_acc))
    
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 1000
batch_size = 1024
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:
# Loss: 2.346452236175537. Validation Accuracy 0.0891088992357254
#
# Epoch  2, CIFAR-10 Batch 1:
# Loss: 2.3274576663970947. Validation Accuracy 0.0891088992357254
#
# Epoch  3, CIFAR-10 Batch 1:
# Loss: 2.316182851791382. Validation Accuracy 0.09034654498100281
#
# Epoch  4, CIFAR-10 Batch 1:
# Loss: 2.3094587326049805. Validation Accuracy 0.09405940771102905
#
# Epoch  5, CIFAR-10 Batch 1:
# Loss: 2.3052496910095215. Validation Accuracy 0.09405940771102905
#
# Epoch  6, CIFAR-10 Batch 1:
# Loss: 2.3022685050964355. Validation Accuracy 0.10148513317108154
#
# Epoch  7, CIFAR-10 Batch 1:
# Loss: 2.299574375152588. Validation Accuracy 0.10767325758934021
#
# Epoch  8, CIFAR-10 Batch 1:
# Loss: 2.2957139015197754. Validation Accuracy 0.1683168262243271
#
# Epoch  9, CIFAR-10 Batch 1:
# Loss: 2.2911267280578613. Validation Accuracy 0.16212871670722961
#
# Epoch 10, CIFAR-10 Batch 1:
# Loss: 2.285071611404419. Validation Accuracy 0.16707921028137207
#
# Epoch 11, CIFAR-10 Batch 1:
# Loss: 2.2770979404449463. Validation Accuracy 0.16460394859313965
#
# Epoch 12, CIFAR-10 Batch 1:
# Loss: 2.269416093826294. Validation Accuracy 0.16460397839546204
#
# Epoch 13, CIFAR-10 Batch 1:
# Loss: 2.2614426612854004. Validation Accuracy 0.16584157943725586
#
# Epoch 14, CIFAR-10 Batch 1:
# Loss: 2.2536370754241943. Validation Accuracy 0.18316832184791565
#
# Epoch 15, CIFAR-10 Batch 1:
# Loss: 2.2451677322387695. Validation Accuracy 0.1967821717262268
#
# Epoch 16, CIFAR-10 Batch 1:
# Loss: 2.2373898029327393. Validation Accuracy 0.2215346395969391
#
# Epoch 17, CIFAR-10 Batch 1:
# Loss: 2.2291746139526367. Validation Accuracy 0.2240099012851715
#
# Epoch 18, CIFAR-10 Batch 1:
# Loss: 2.2209346294403076. Validation Accuracy 0.22896037995815277
#
# Epoch 19, CIFAR-10 Batch 1:
# Loss: 2.212801218032837. Validation Accuracy 0.23391088843345642
#
# Epoch 20, CIFAR-10 Batch 1:
# Loss: 2.2050092220306396. Validation Accuracy 0.24257424473762512
#
# Epoch 21, CIFAR-10 Batch 1:
# Loss: 2.1974971294403076. Validation Accuracy 0.23886138200759888
#
# Epoch 22, CIFAR-10 Batch 1:
# Loss: 2.1897523403167725. Validation Accuracy 0.2413366287946701
#
# Epoch 23, CIFAR-10 Batch 1:
# Loss: 2.182276725769043. Validation Accuracy 0.25495046377182007
#
# Epoch 24, CIFAR-10 Batch 1:
# Loss: 2.174842357635498. Validation Accuracy 0.2599009871482849
#
# Epoch 25, CIFAR-10 Batch 1:
# Loss: 2.167344093322754. Validation Accuracy 0.27103957533836365
#
# Epoch 26, CIFAR-10 Batch 1:
# Loss: 2.1599178314208984. Validation Accuracy 0.2772276997566223
#
# Epoch 27, CIFAR-10 Batch 1:
# Loss: 2.152714967727661. Validation Accuracy 0.2784653306007385
#
# Epoch 28, CIFAR-10 Batch 1:
# Loss: 2.1446170806884766. Validation Accuracy 0.2784653306007385
#
# Epoch 29, CIFAR-10 Batch 1:
# Loss: 2.1379146575927734. Validation Accuracy 0.2759900987148285
#
# Epoch 30, CIFAR-10 Batch 1:
# Loss: 2.1307878494262695. Validation Accuracy 0.2846534848213196
#
# Epoch 31, CIFAR-10 Batch 1:
# Loss: 2.1239449977874756. Validation Accuracy 0.28960394859313965
#
# Epoch 32, CIFAR-10 Batch 1:
# Loss: 2.1173183917999268. Validation Accuracy 0.2920791804790497
#
# Epoch 33, CIFAR-10 Batch 1:
# Loss: 2.1107521057128906. Validation Accuracy 0.2970297038555145
#
# Epoch 34, CIFAR-10 Batch 1:
# Loss: 2.1034371852874756. Validation Accuracy 0.2970297038555145
#
# Epoch 35, CIFAR-10 Batch 1:
# Loss: 2.097017288208008. Validation Accuracy 0.3032178282737732
#
# Epoch 36, CIFAR-10 Batch 1:
# Loss: 2.089876890182495. Validation Accuracy 0.3044554591178894
#
# Epoch 37, CIFAR-10 Batch 1:
# Loss: 2.0833022594451904. Validation Accuracy 0.30940595269203186
#
# Epoch 38, CIFAR-10 Batch 1:
# Loss: 2.076847553253174. Validation Accuracy 0.3118811547756195
#
# Epoch 39, CIFAR-10 Batch 1:
# Loss: 2.069478988647461. Validation Accuracy 0.3118811845779419
#
# Epoch 40, CIFAR-10 Batch 1:
# Loss: 2.062311887741089. Validation Accuracy 0.31683170795440674
#
# Epoch 41, CIFAR-10 Batch 1:
# Loss: 2.0560085773468018. Validation Accuracy 0.31435641646385193
#
# Epoch 42, CIFAR-10 Batch 1:
# Loss: 2.0504536628723145. Validation Accuracy 0.3131188154220581
#
# Epoch 43, CIFAR-10 Batch 1:
# Loss: 2.043832540512085. Validation Accuracy 0.31064358353614807
#
# Epoch 44, CIFAR-10 Batch 1:
# Loss: 2.0364818572998047. Validation Accuracy 0.3217821717262268
#
# Epoch 45, CIFAR-10 Batch 1:
# Loss: 2.0294816493988037. Validation Accuracy 0.3193069398403168
#
# Epoch 46, CIFAR-10 Batch 1:
# Loss: 2.0217537879943848. Validation Accuracy 0.31806930899620056
#
# Epoch 47, CIFAR-10 Batch 1:
# Loss: 2.017904043197632. Validation Accuracy 0.3143564462661743
#
# Epoch 48, CIFAR-10 Batch 1:
# Loss: 2.0110719203948975. Validation Accuracy 0.31559404730796814
#
# Epoch 49, CIFAR-10 Batch 1:
# Loss: 2.0032668113708496. Validation Accuracy 0.3304455578327179
#
# Epoch 50, CIFAR-10 Batch 1:
# Loss: 1.995699405670166. Validation Accuracy 0.3378712832927704
#
# Epoch 51, CIFAR-10 Batch 1:
# Loss: 1.9899928569793701. Validation Accuracy 0.33292078971862793
#
# Epoch 52, CIFAR-10 Batch 1:
# Loss: 1.9843566417694092. Validation Accuracy 0.33415845036506653
#
# Epoch 53, CIFAR-10 Batch 1:
# Loss: 1.9788553714752197. Validation Accuracy 0.33415839076042175
#
# Epoch 54, CIFAR-10 Batch 1:
# Loss: 1.9735603332519531. Validation Accuracy 0.34158414602279663
#
# Epoch 55, CIFAR-10 Batch 1:
# Loss: 1.9686636924743652. Validation Accuracy 0.34158414602279663
#
# Epoch 56, CIFAR-10 Batch 1:
# Loss: 1.9607133865356445. Validation Accuracy 0.3502475321292877
#
# Epoch 57, CIFAR-10 Batch 1:
# Loss: 1.9559895992279053. Validation Accuracy 0.3415842056274414
#
# Epoch 58, CIFAR-10 Batch 1:
# Loss: 1.9485230445861816. Validation Accuracy 0.34405940771102905
#
# Epoch 59, CIFAR-10 Batch 1:
# Loss: 1.9426803588867188. Validation Accuracy 0.3465346097946167
#
# Epoch 60, CIFAR-10 Batch 1:
# Loss: 1.9374537467956543. Validation Accuracy 0.3576732873916626
#
# Epoch 61, CIFAR-10 Batch 1:
# Loss: 1.9309666156768799. Validation Accuracy 0.356435626745224
#
# Epoch 62, CIFAR-10 Batch 1:
# Loss: 1.924532175064087. Validation Accuracy 0.35396039485931396
#
# Epoch 63, CIFAR-10 Batch 1:
# Loss: 1.9188225269317627. Validation Accuracy 0.35148513317108154
#
# Epoch 64, CIFAR-10 Batch 1:
# Loss: 1.9144258499145508. Validation Accuracy 0.35272276401519775
#
# Epoch 65, CIFAR-10 Batch 1:
# Loss: 1.908571481704712. Validation Accuracy 0.35148513317108154
#
# Epoch 66, CIFAR-10 Batch 1:
# Loss: 1.9027379751205444. Validation Accuracy 0.3502475321292877
#
# Epoch 67, CIFAR-10 Batch 1:
# Loss: 1.8977360725402832. Validation Accuracy 0.36014848947525024
#
# Epoch 68, CIFAR-10 Batch 1:
# Loss: 1.893375039100647. Validation Accuracy 0.36262375116348267
#
# Epoch 69, CIFAR-10 Batch 1:
# Loss: 1.8883202075958252. Validation Accuracy 0.36138612031936646
#
# Epoch 70, CIFAR-10 Batch 1:
# Loss: 1.882621169090271. Validation Accuracy 0.36262375116348267
#
# Epoch 71, CIFAR-10 Batch 1:
# Loss: 1.8753721714019775. Validation Accuracy 0.36138612031936646
#
# Epoch 72, CIFAR-10 Batch 1:
# Loss: 1.873531699180603. Validation Accuracy 0.3663366436958313
#
# Epoch 73, CIFAR-10 Batch 1:
# Loss: 1.872627854347229. Validation Accuracy 0.3638613820075989
#
# Epoch 74, CIFAR-10 Batch 1:
# Loss: 1.8668067455291748. Validation Accuracy 0.3688119053840637
#
# Epoch 75, CIFAR-10 Batch 1:
# Loss: 1.8607500791549683. Validation Accuracy 0.36138615012168884
#
# Epoch 76, CIFAR-10 Batch 1:
# Loss: 1.8549869060516357. Validation Accuracy 0.3688119053840637
#
# Epoch 77, CIFAR-10 Batch 1:
# Loss: 1.8492228984832764. Validation Accuracy 0.3638613820075989
#
# Epoch 78, CIFAR-10 Batch 1:
# Loss: 1.843753457069397. Validation Accuracy 0.37128710746765137
#
# Epoch 79, CIFAR-10 Batch 1:
# Loss: 1.8394807577133179. Validation Accuracy 0.3663366436958313
#
# Epoch 80, CIFAR-10 Batch 1:
# Loss: 1.8372232913970947. Validation Accuracy 0.3725247383117676
#
# Epoch 81, CIFAR-10 Batch 1:
# Loss: 1.8349717855453491. Validation Accuracy 0.3725247383117676
#
# Epoch 82, CIFAR-10 Batch 1:
# Loss: 1.828561782836914. Validation Accuracy 0.3762376308441162
#
# Epoch 83, CIFAR-10 Batch 1:
# Loss: 1.8228745460510254. Validation Accuracy 0.37747523188591003
#
# Epoch 84, CIFAR-10 Batch 1:
# Loss: 1.8181161880493164. Validation Accuracy 0.37871289253234863
#
# Epoch 85, CIFAR-10 Batch 1:
# Loss: 1.812934160232544. Validation Accuracy 0.3849009573459625
#
# Epoch 86, CIFAR-10 Batch 1:
# Loss: 1.8099086284637451. Validation Accuracy 0.3762376308441162
#
# Epoch 87, CIFAR-10 Batch 1:
# Loss: 1.8078111410140991. Validation Accuracy 0.37747523188591003
#
# Epoch 88, CIFAR-10 Batch 1:
# Loss: 1.8031965494155884. Validation Accuracy 0.37995046377182007
#
# Epoch 89, CIFAR-10 Batch 1:
# Loss: 1.7991209030151367. Validation Accuracy 0.3849009871482849
#
# Epoch 90, CIFAR-10 Batch 1:
# Loss: 1.796863317489624. Validation Accuracy 0.38861384987831116
#
# Epoch 91, CIFAR-10 Batch 1:
# Loss: 1.7949447631835938. Validation Accuracy 0.38737621903419495
#
# Epoch 92, CIFAR-10 Batch 1:
# Loss: 1.7946295738220215. Validation Accuracy 0.38985151052474976
#
# Epoch 93, CIFAR-10 Batch 1:
# Loss: 1.7909098863601685. Validation Accuracy 0.38985148072242737
#
# Epoch 94, CIFAR-10 Batch 1:
# Loss: 1.7810022830963135. Validation Accuracy 0.3923267424106598
#
# Epoch 95, CIFAR-10 Batch 1:
# Loss: 1.7771191596984863. Validation Accuracy 0.3923267424106598
#
# Epoch 96, CIFAR-10 Batch 1:
# Loss: 1.7807800769805908. Validation Accuracy 0.3923267126083374
#
# Epoch 97, CIFAR-10 Batch 1:
# Loss: 1.784927487373352. Validation Accuracy 0.38737618923187256
#
# Epoch 98, CIFAR-10 Batch 1:
# Loss: 1.7970725297927856. Validation Accuracy 0.3836633861064911
#
# Epoch 99, CIFAR-10 Batch 1:
# Loss: 1.8506163358688354. Validation Accuracy 0.3650989830493927
#
# Epoch 100, CIFAR-10 Batch 1:
# Loss: 1.8202519416809082. Validation Accuracy 0.37128710746765137
#
# Epoch 101, CIFAR-10 Batch 1:
# Loss: 1.8448538780212402. Validation Accuracy 0.3502475619316101
#
# Epoch 102, CIFAR-10 Batch 1:
# Loss: 1.809185266494751. Validation Accuracy 0.36881187558174133
#
# Epoch 103, CIFAR-10 Batch 1:
# Loss: 1.767822504043579. Validation Accuracy 0.38861387968063354
#
# Epoch 104, CIFAR-10 Batch 1:
# Loss: 1.7614234685897827. Validation Accuracy 0.39603957533836365
#
# Epoch 105, CIFAR-10 Batch 1:
# Loss: 1.7587393522262573. Validation Accuracy 0.393564373254776
#
# Epoch 106, CIFAR-10 Batch 1:
# Loss: 1.7602226734161377. Validation Accuracy 0.38861384987831116
#
# Epoch 107, CIFAR-10 Batch 1:
# Loss: 1.7614670991897583. Validation Accuracy 0.3836633861064911
#
# Epoch 108, CIFAR-10 Batch 1:
# Loss: 1.7623051404953003. Validation Accuracy 0.3836633563041687
#
# Epoch 109, CIFAR-10 Batch 1:
# Loss: 1.7582039833068848. Validation Accuracy 0.3836633265018463
#
# Epoch 110, CIFAR-10 Batch 1:
# Loss: 1.7502737045288086. Validation Accuracy 0.3849009871482849
#
# Epoch 111, CIFAR-10 Batch 1:
# Loss: 1.7436110973358154. Validation Accuracy 0.38737621903419495
#
# Epoch 112, CIFAR-10 Batch 1:
# Loss: 1.738350510597229. Validation Accuracy 0.393564373254776
#
# Epoch 113, CIFAR-10 Batch 1:
# Loss: 1.734866738319397. Validation Accuracy 0.3910891115665436
#
# Epoch 114, CIFAR-10 Batch 1:
# Loss: 1.7321531772613525. Validation Accuracy 0.3910891115665436
#
# Epoch 115, CIFAR-10 Batch 1:
# Loss: 1.7293059825897217. Validation Accuracy 0.3923267424106598
#
# Epoch 116, CIFAR-10 Batch 1:
# Loss: 1.7266119718551636. Validation Accuracy 0.393564373254776
#
# Epoch 117, CIFAR-10 Batch 1:
# Loss: 1.724982738494873. Validation Accuracy 0.3948019742965698
#
# Epoch 118, CIFAR-10 Batch 1:
# Loss: 1.7235653400421143. Validation Accuracy 0.3923267126083374
#
# Epoch 119, CIFAR-10 Batch 1:
# Loss: 1.7225526571273804. Validation Accuracy 0.38737621903419495
#
# Epoch 120, CIFAR-10 Batch 1:
# Loss: 1.7222057580947876. Validation Accuracy 0.3849009573459625
#
# Epoch 121, CIFAR-10 Batch 1:
# Loss: 1.7215664386749268. Validation Accuracy 0.3824257254600525
#
# Epoch 122, CIFAR-10 Batch 1:
# Loss: 1.7196037769317627. Validation Accuracy 0.3849009871482849
#
# Epoch 123, CIFAR-10 Batch 1:
# Loss: 1.7155468463897705. Validation Accuracy 0.38737621903419495
#
# Epoch 124, CIFAR-10 Batch 1:
# Loss: 1.711219310760498. Validation Accuracy 0.38737621903419495
#
# Epoch 125, CIFAR-10 Batch 1:
# Loss: 1.706748366355896. Validation Accuracy 0.38861384987831116
#
# Epoch 126, CIFAR-10 Batch 1:
# Loss: 1.7021238803863525. Validation Accuracy 0.3935643434524536
#
# Epoch 127, CIFAR-10 Batch 1:
# Loss: 1.6981955766677856. Validation Accuracy 0.393564373254776
#
# Epoch 128, CIFAR-10 Batch 1:
# Loss: 1.6938244104385376. Validation Accuracy 0.39727723598480225
#
# Epoch 129, CIFAR-10 Batch 1:
# Loss: 1.690438985824585. Validation Accuracy 0.39727723598480225
#
# Epoch 130, CIFAR-10 Batch 1:
# Loss: 1.6875742673873901. Validation Accuracy 0.39851486682891846
#
# Epoch 131, CIFAR-10 Batch 1:
# Loss: 1.6852033138275146. Validation Accuracy 0.39851486682891846
#
# Epoch 132, CIFAR-10 Batch 1:
# Loss: 1.6824166774749756. Validation Accuracy 0.4022276997566223
#
# Epoch 133, CIFAR-10 Batch 1:
# Loss: 1.6796809434890747. Validation Accuracy 0.40594059228897095
#
# Epoch 134, CIFAR-10 Batch 1:
# Loss: 1.677661657333374. Validation Accuracy 0.408415824174881
#
# Epoch 135, CIFAR-10 Batch 1:
# Loss: 1.6755561828613281. Validation Accuracy 0.410891056060791
#
# Epoch 136, CIFAR-10 Batch 1:
# Loss: 1.6725810766220093. Validation Accuracy 0.410891056060791
#
# Epoch 137, CIFAR-10 Batch 1:
# Loss: 1.6703176498413086. Validation Accuracy 0.40717819333076477
#
# Epoch 138, CIFAR-10 Batch 1:
# Loss: 1.669495940208435. Validation Accuracy 0.4034653306007385
#
# Epoch 139, CIFAR-10 Batch 1:
# Loss: 1.6683783531188965. Validation Accuracy 0.40470296144485474
#
# Epoch 140, CIFAR-10 Batch 1:
# Loss: 1.6664704084396362. Validation Accuracy 0.40717819333076477
#
# Epoch 141, CIFAR-10 Batch 1:
# Loss: 1.6640350818634033. Validation Accuracy 0.4108910858631134
#
# Epoch 142, CIFAR-10 Batch 1:
# Loss: 1.6613969802856445. Validation Accuracy 0.41460394859313965
#
# Epoch 143, CIFAR-10 Batch 1:
# Loss: 1.6598153114318848. Validation Accuracy 0.4170791804790497
#
# Epoch 144, CIFAR-10 Batch 1:
# Loss: 1.6596410274505615. Validation Accuracy 0.42202967405319214
#
# Epoch 145, CIFAR-10 Batch 1:
# Loss: 1.6598271131515503. Validation Accuracy 0.4195544123649597
#
# Epoch 146, CIFAR-10 Batch 1:
# Loss: 1.6585893630981445. Validation Accuracy 0.4133663475513458
#
# Epoch 147, CIFAR-10 Batch 1:
# Loss: 1.6604505777359009. Validation Accuracy 0.408415824174881
#
# Epoch 148, CIFAR-10 Batch 1:
# Loss: 1.6619274616241455. Validation Accuracy 0.40594059228897095
#
# Epoch 149, CIFAR-10 Batch 1:
# Loss: 1.6594164371490479. Validation Accuracy 0.40841585397720337
#
# Epoch 150, CIFAR-10 Batch 1:
# Loss: 1.6492990255355835. Validation Accuracy 0.41707921028137207
#
# Epoch 151, CIFAR-10 Batch 1:
# Loss: 1.6499882936477661. Validation Accuracy 0.4207920432090759
#
# Epoch 152, CIFAR-10 Batch 1:
# Loss: 1.6441158056259155. Validation Accuracy 0.4121286869049072
#
# Epoch 153, CIFAR-10 Batch 1:
# Loss: 1.6488937139511108. Validation Accuracy 0.4121286869049072
#
# Epoch 154, CIFAR-10 Batch 1:
# Loss: 1.6520180702209473. Validation Accuracy 0.41460394859313965
#
# Epoch 155, CIFAR-10 Batch 1:
# Loss: 1.6512839794158936. Validation Accuracy 0.41460394859313965
#
# Epoch 156, CIFAR-10 Batch 1:
# Loss: 1.6453807353973389. Validation Accuracy 0.41460394859313965
#
# Epoch 157, CIFAR-10 Batch 1:
# Loss: 1.6417666673660278. Validation Accuracy 0.41584154963493347
#
# Epoch 158, CIFAR-10 Batch 1:
# Loss: 1.6371773481369019. Validation Accuracy 0.41460394859313965
#
# Epoch 159, CIFAR-10 Batch 1:
# Loss: 1.6356287002563477. Validation Accuracy 0.4183168411254883
#
# Epoch 160, CIFAR-10 Batch 1:
# Loss: 1.6376757621765137. Validation Accuracy 0.4183167815208435
#
# Epoch 161, CIFAR-10 Batch 1:
# Loss: 1.6407119035720825. Validation Accuracy 0.4195544123649597
#
# Epoch 162, CIFAR-10 Batch 1:
# Loss: 1.6417206525802612. Validation Accuracy 0.41584157943725586
#
# Epoch 163, CIFAR-10 Batch 1:
# Loss: 1.6408765316009521. Validation Accuracy 0.4170791506767273
#
# Epoch 164, CIFAR-10 Batch 1:
# Loss: 1.639631986618042. Validation Accuracy 0.4207920730113983
#
# Epoch 165, CIFAR-10 Batch 1:
# Loss: 1.6398391723632812. Validation Accuracy 0.4207920730113983
#
# Epoch 166, CIFAR-10 Batch 1:
# Loss: 1.6492546796798706. Validation Accuracy 0.41584154963493347
#
# Epoch 167, CIFAR-10 Batch 1:
# Loss: 1.6547117233276367. Validation Accuracy 0.41584154963493347
#
# Epoch 168, CIFAR-10 Batch 1:
# Loss: 1.6543378829956055. Validation Accuracy 0.41336631774902344
#
# Epoch 169, CIFAR-10 Batch 1:
# Loss: 1.6505879163742065. Validation Accuracy 0.4108910858631134
#
# Epoch 170, CIFAR-10 Batch 1:
# Loss: 1.6371899843215942. Validation Accuracy 0.41460394859313965
#
# Epoch 171, CIFAR-10 Batch 1:
# Loss: 1.6226204633712769. Validation Accuracy 0.4183167815208435
#
# Epoch 172, CIFAR-10 Batch 1:
# Loss: 1.6230002641677856. Validation Accuracy 0.41584157943725586
#
# Epoch 173, CIFAR-10 Batch 1:
# Loss: 1.6844165325164795. Validation Accuracy 0.3861386179924011
#
# Epoch 174, CIFAR-10 Batch 1:
# Loss: 1.7487417459487915. Validation Accuracy 0.36138612031936646
#
# Epoch 175, CIFAR-10 Batch 1:
# Loss: 1.6775094270706177. Validation Accuracy 0.3861386179924011
#
# Epoch 176, CIFAR-10 Batch 1:
# Loss: 1.618269681930542. Validation Accuracy 0.4121287167072296
#
# Epoch 177, CIFAR-10 Batch 1:
# Loss: 1.6046733856201172. Validation Accuracy 0.4195544123649597
#
# Epoch 178, CIFAR-10 Batch 1:
# Loss: 1.6016401052474976. Validation Accuracy 0.4170791804790497
#
# Epoch 179, CIFAR-10 Batch 1:
# Loss: 1.6010335683822632. Validation Accuracy 0.41336631774902344
#
# Epoch 180, CIFAR-10 Batch 1:
# Loss: 1.6019394397735596. Validation Accuracy 0.41584157943725586
#
# Epoch 181, CIFAR-10 Batch 1:
# Loss: 1.6025015115737915. Validation Accuracy 0.41584157943725586
#
# Epoch 182, CIFAR-10 Batch 1:
# Loss: 1.6034226417541504. Validation Accuracy 0.4133663475513458
#
# Epoch 183, CIFAR-10 Batch 1:
# Loss: 1.6027827262878418. Validation Accuracy 0.4121287167072296
#
# Epoch 184, CIFAR-10 Batch 1:
# Loss: 1.5993608236312866. Validation Accuracy 0.412128746509552
#
# Epoch 185, CIFAR-10 Batch 1:
# Loss: 1.5966278314590454. Validation Accuracy 0.4108911156654358
#
# Epoch 186, CIFAR-10 Batch 1:
# Loss: 1.5946323871612549. Validation Accuracy 0.4121287167072296
#
# Epoch 187, CIFAR-10 Batch 1:
# Loss: 1.5908503532409668. Validation Accuracy 0.41460397839546204
#
# Epoch 188, CIFAR-10 Batch 1:
# Loss: 1.5838991403579712. Validation Accuracy 0.4195544123649597
#
# Epoch 189, CIFAR-10 Batch 1:
# Loss: 1.57720947265625. Validation Accuracy 0.4183168411254883
#
# Epoch 190, CIFAR-10 Batch 1:
# Loss: 1.5719982385635376. Validation Accuracy 0.4207920432090759
#
# Epoch 191, CIFAR-10 Batch 1:
# Loss: 1.5682361125946045. Validation Accuracy 0.42326730489730835
#
# Epoch 192, CIFAR-10 Batch 1:
# Loss: 1.5660828351974487. Validation Accuracy 0.42326730489730835
#
# Epoch 193, CIFAR-10 Batch 1:
# Loss: 1.5646589994430542. Validation Accuracy 0.42450493574142456
#
# Epoch 194, CIFAR-10 Batch 1:
# Loss: 1.563370943069458. Validation Accuracy 0.42574256658554077
#
# Epoch 195, CIFAR-10 Batch 1:
# Loss: 1.5621955394744873. Validation Accuracy 0.42326730489730835
#
# Epoch 196, CIFAR-10 Batch 1:
# Loss: 1.5604236125946045. Validation Accuracy 0.42326730489730835
#
# Epoch 197, CIFAR-10 Batch 1:
# Loss: 1.5586743354797363. Validation Accuracy 0.42326730489730835
#
# Epoch 198, CIFAR-10 Batch 1:
# Loss: 1.5563782453536987. Validation Accuracy 0.42326730489730835
#
# Epoch 199, CIFAR-10 Batch 1:
# Loss: 1.5544161796569824. Validation Accuracy 0.42450493574142456
#
# Epoch 200, CIFAR-10 Batch 1:
# Loss: 1.5517984628677368. Validation Accuracy 0.42326730489730835
#
# Epoch 201, CIFAR-10 Batch 1:
# Loss: 1.5491102933883667. Validation Accuracy 0.4207920432090759
#
# Epoch 202, CIFAR-10 Batch 1:
# Loss: 1.547061800956726. Validation Accuracy 0.4207920432090759
#
# Epoch 203, CIFAR-10 Batch 1:
# Loss: 1.5457788705825806. Validation Accuracy 0.42326733469963074
#
# Epoch 204, CIFAR-10 Batch 1:
# Loss: 1.5455715656280518. Validation Accuracy 0.42450493574142456
#
# Epoch 205, CIFAR-10 Batch 1:
# Loss: 1.5447441339492798. Validation Accuracy 0.426980197429657
#
# Epoch 206, CIFAR-10 Batch 1:
# Loss: 1.5431098937988281. Validation Accuracy 0.4282177984714508
#
# Epoch 207, CIFAR-10 Batch 1:
# Loss: 1.5407963991165161. Validation Accuracy 0.43193066120147705
#
# Epoch 208, CIFAR-10 Batch 1:
# Loss: 1.539306402206421. Validation Accuracy 0.429455429315567
#
# Epoch 209, CIFAR-10 Batch 1:
# Loss: 1.538793921470642. Validation Accuracy 0.4306930601596832
#
# Epoch 210, CIFAR-10 Batch 1:
# Loss: 1.5388591289520264. Validation Accuracy 0.426980197429657
#
# Epoch 211, CIFAR-10 Batch 1:
# Loss: 1.5387929677963257. Validation Accuracy 0.426980197429657
#
# Epoch 212, CIFAR-10 Batch 1:
# Loss: 1.5386136770248413. Validation Accuracy 0.4269801676273346
#
# Epoch 213, CIFAR-10 Batch 1:
# Loss: 1.5376865863800049. Validation Accuracy 0.4282177984714508
#
# Epoch 214, CIFAR-10 Batch 1:
# Loss: 1.5365726947784424. Validation Accuracy 0.42945539951324463
#
# Epoch 215, CIFAR-10 Batch 1:
# Loss: 1.5354958772659302. Validation Accuracy 0.4306930601596832
#
# Epoch 216, CIFAR-10 Batch 1:
# Loss: 1.5346643924713135. Validation Accuracy 0.4306930899620056
#
# Epoch 217, CIFAR-10 Batch 1:
# Loss: 1.5333856344223022. Validation Accuracy 0.43069303035736084
#
# Epoch 218, CIFAR-10 Batch 1:
# Loss: 1.5324293375015259. Validation Accuracy 0.42945539951324463
#
# Epoch 219, CIFAR-10 Batch 1:
# Loss: 1.5347480773925781. Validation Accuracy 0.4269801676273346
#
# Epoch 220, CIFAR-10 Batch 1:
# Loss: 1.54340398311615. Validation Accuracy 0.43316829204559326
#
# Epoch 221, CIFAR-10 Batch 1:
# Loss: 1.5605605840682983. Validation Accuracy 0.42326730489730835
#
# Epoch 222, CIFAR-10 Batch 1:
# Loss: 1.5516430139541626. Validation Accuracy 0.4183168113231659
#
# Epoch 223, CIFAR-10 Batch 1:
# Loss: 1.551800012588501. Validation Accuracy 0.4195544719696045
#
# Epoch 224, CIFAR-10 Batch 1:
# Loss: 1.552791953086853. Validation Accuracy 0.4220297038555145
#
# Epoch 225, CIFAR-10 Batch 1:
# Loss: 1.5553851127624512. Validation Accuracy 0.4207920730113983
#
# Epoch 226, CIFAR-10 Batch 1:
# Loss: 1.548054814338684. Validation Accuracy 0.42450493574142456
#
# Epoch 227, CIFAR-10 Batch 1:
# Loss: 1.5498933792114258. Validation Accuracy 0.4183168411254883
#
# Epoch 228, CIFAR-10 Batch 1:
# Loss: 1.5596109628677368. Validation Accuracy 0.4207921028137207
#
# Epoch 229, CIFAR-10 Batch 1:
# Loss: 1.5591880083084106. Validation Accuracy 0.41707921028137207
#
# Epoch 230, CIFAR-10 Batch 1:
# Loss: 1.5514225959777832. Validation Accuracy 0.4220297038555145
#
# Epoch 231, CIFAR-10 Batch 1:
# Loss: 1.54628324508667. Validation Accuracy 0.4207920730113983
#
# Epoch 232, CIFAR-10 Batch 1:
# Loss: 1.5553431510925293. Validation Accuracy 0.42450493574142456
#
# Epoch 233, CIFAR-10 Batch 1:
# Loss: 1.5424185991287231. Validation Accuracy 0.4269801378250122
#
# Epoch 234, CIFAR-10 Batch 1:
# Loss: 1.5241471529006958. Validation Accuracy 0.42574256658554077
#
# Epoch 235, CIFAR-10 Batch 1:
# Loss: 1.5544829368591309. Validation Accuracy 0.4183168411254883
#
# Epoch 236, CIFAR-10 Batch 1:
# Loss: 1.579740047454834. Validation Accuracy 0.4195544421672821
#
# Epoch 237, CIFAR-10 Batch 1:
# Loss: 1.5812945365905762. Validation Accuracy 0.41584157943725586
#
# Epoch 238, CIFAR-10 Batch 1:
# Loss: 1.5558029413223267. Validation Accuracy 0.4207920432090759
#
# Epoch 239, CIFAR-10 Batch 1:
# Loss: 1.5256869792938232. Validation Accuracy 0.42945539951324463
#
# Epoch 240, CIFAR-10 Batch 1:
# Loss: 1.5151922702789307. Validation Accuracy 0.42450493574142456
#
# Epoch 241, CIFAR-10 Batch 1:
# Loss: 1.5050803422927856. Validation Accuracy 0.4282177686691284
#
# Epoch 242, CIFAR-10 Batch 1:
# Loss: 1.503633975982666. Validation Accuracy 0.429455429315567
#
# Epoch 243, CIFAR-10 Batch 1:
# Loss: 1.5030395984649658. Validation Accuracy 0.429455429315567
#
# Epoch 244, CIFAR-10 Batch 1:
# Loss: 1.5027490854263306. Validation Accuracy 0.426980197429657
#
# Epoch 245, CIFAR-10 Batch 1:
# Loss: 1.5030882358551025. Validation Accuracy 0.4282177686691284
#
# Epoch 246, CIFAR-10 Batch 1:
# Loss: 1.5025264024734497. Validation Accuracy 0.4282178282737732
#
# Epoch 247, CIFAR-10 Batch 1:
# Loss: 1.50137460231781. Validation Accuracy 0.4282178282737732
#
# Epoch 248, CIFAR-10 Batch 1:
# Loss: 1.502004623413086. Validation Accuracy 0.42326730489730835
#
# Epoch 249, CIFAR-10 Batch 1:
# Loss: 1.5035580396652222. Validation Accuracy 0.42202967405319214
#
# Epoch 250, CIFAR-10 Batch 1:
# Loss: 1.5029881000518799. Validation Accuracy 0.42450493574142456
#
# Epoch 251, CIFAR-10 Batch 1:
# Loss: 1.503063678741455. Validation Accuracy 0.4207920432090759
#
# Epoch 252, CIFAR-10 Batch 1:
# Loss: 1.5038820505142212. Validation Accuracy 0.4207920432090759
#
# Epoch 253, CIFAR-10 Batch 1:
# Loss: 1.5047452449798584. Validation Accuracy 0.42202967405319214
#
# Epoch 254, CIFAR-10 Batch 1:
# Loss: 1.5062525272369385. Validation Accuracy 0.4207920432090759
#
# Epoch 255, CIFAR-10 Batch 1:
# Loss: 1.50693678855896. Validation Accuracy 0.4195544719696045
#
# Epoch 256, CIFAR-10 Batch 1:
# Loss: 1.5091321468353271. Validation Accuracy 0.4207920432090759
#
# Epoch 257, CIFAR-10 Batch 1:
# Loss: 1.5115468502044678. Validation Accuracy 0.42202967405319214
#
# Epoch 258, CIFAR-10 Batch 1:
# Loss: 1.5126640796661377. Validation Accuracy 0.42326730489730835
#
# Epoch 259, CIFAR-10 Batch 1:
# Loss: 1.5114026069641113. Validation Accuracy 0.4207920432090759
#
# Epoch 260, CIFAR-10 Batch 1:
# Loss: 1.5095608234405518. Validation Accuracy 0.42202967405319214
#
# Epoch 261, CIFAR-10 Batch 1:
# Loss: 1.5100113153457642. Validation Accuracy 0.42326730489730835
#
# Epoch 262, CIFAR-10 Batch 1:
# Loss: 1.5134721994400024. Validation Accuracy 0.42202967405319214
#
# Epoch 263, CIFAR-10 Batch 1:
# Loss: 1.5141689777374268. Validation Accuracy 0.42450493574142456
#
# Epoch 264, CIFAR-10 Batch 1:
# Loss: 1.5066041946411133. Validation Accuracy 0.42450493574142456
#
# Epoch 265, CIFAR-10 Batch 1:
# Loss: 1.5053679943084717. Validation Accuracy 0.426980197429657
#
# Epoch 266, CIFAR-10 Batch 1:
# Loss: 1.5001696348190308. Validation Accuracy 0.426980197429657
#
# Epoch 267, CIFAR-10 Batch 1:
# Loss: 1.4917782545089722. Validation Accuracy 0.4282178282737732
#
# Epoch 268, CIFAR-10 Batch 1:
# Loss: 1.5031882524490356. Validation Accuracy 0.42945539951324463
#
# Epoch 269, CIFAR-10 Batch 1:
# Loss: 1.5184448957443237. Validation Accuracy 0.4306930601596832
#
# Epoch 270, CIFAR-10 Batch 1:
# Loss: 1.5110795497894287. Validation Accuracy 0.4282178282737732
#
# Epoch 271, CIFAR-10 Batch 1:
# Loss: 1.5248303413391113. Validation Accuracy 0.4294554591178894
#
# Epoch 272, CIFAR-10 Batch 1:
# Loss: 1.5398377180099487. Validation Accuracy 0.43316829204559326
#
# Epoch 273, CIFAR-10 Batch 1:
# Loss: 1.536501169204712. Validation Accuracy 0.43193066120147705
#
# Epoch 274, CIFAR-10 Batch 1:
# Loss: 1.560813069343567. Validation Accuracy 0.42326730489730835
#
# Epoch 275, CIFAR-10 Batch 1:
# Loss: 1.567110538482666. Validation Accuracy 0.41584154963493347
#
# Epoch 276, CIFAR-10 Batch 1:
# Loss: 1.5396705865859985. Validation Accuracy 0.42574256658554077
#
# Epoch 277, CIFAR-10 Batch 1:
# Loss: 1.5277345180511475. Validation Accuracy 0.42202967405319214
#
# Epoch 278, CIFAR-10 Batch 1:
# Loss: 1.5576913356781006. Validation Accuracy 0.4183168411254883
#
# Epoch 279, CIFAR-10 Batch 1:
# Loss: 1.602432131767273. Validation Accuracy 0.41707921028137207
#
# Epoch 280, CIFAR-10 Batch 1:
# Loss: 1.6060748100280762. Validation Accuracy 0.41336631774902344
#
# Epoch 281, CIFAR-10 Batch 1:
# Loss: 1.5979022979736328. Validation Accuracy 0.41460391879081726
#
# Epoch 282, CIFAR-10 Batch 1:
# Loss: 1.6177563667297363. Validation Accuracy 0.40841585397720337
#
# Epoch 283, CIFAR-10 Batch 1:
# Loss: 1.6984763145446777. Validation Accuracy 0.3910891115665436
#
# Epoch 284, CIFAR-10 Batch 1:
# Loss: 1.6005163192749023. Validation Accuracy 0.4096534550189972
#
# Epoch 285, CIFAR-10 Batch 1:
# Loss: 1.7283823490142822. Validation Accuracy 0.3477722704410553
#
# Epoch 286, CIFAR-10 Batch 1:
# Loss: 1.7299047708511353. Validation Accuracy 0.3477722704410553
#
# Epoch 287, CIFAR-10 Batch 1:
# Loss: 1.572716474533081. Validation Accuracy 0.40594059228897095
#
# Epoch 288, CIFAR-10 Batch 1:
# Loss: 1.5379847288131714. Validation Accuracy 0.4121287167072296
#
# Epoch 289, CIFAR-10 Batch 1:
# Loss: 1.5509083271026611. Validation Accuracy 0.4108911156654358
#
# Epoch 290, CIFAR-10 Batch 1:
# Loss: 1.58818519115448. Validation Accuracy 0.39603960514068604
#
# Epoch 291, CIFAR-10 Batch 1:
# Loss: 1.6354204416275024. Validation Accuracy 0.3824257254600525
#
# Epoch 292, CIFAR-10 Batch 1:
# Loss: 1.6405565738677979. Validation Accuracy 0.3824257254600525
#
# Epoch 293, CIFAR-10 Batch 1:
# Loss: 1.582567811012268. Validation Accuracy 0.4009900987148285
#
# Epoch 294, CIFAR-10 Batch 1:
# Loss: 1.5357134342193604. Validation Accuracy 0.4183168411254883
#
# Epoch 295, CIFAR-10 Batch 1:
# Loss: 1.5138050317764282. Validation Accuracy 0.426980197429657
#
# Epoch 296, CIFAR-10 Batch 1:
# Loss: 1.509041666984558. Validation Accuracy 0.426980197429657
#
# Epoch 297, CIFAR-10 Batch 1:
# Loss: 1.5099644660949707. Validation Accuracy 0.42450493574142456
#
# Epoch 298, CIFAR-10 Batch 1:
# Loss: 1.5179314613342285. Validation Accuracy 0.4170791804790497
#
# Epoch 299, CIFAR-10 Batch 1:
# Loss: 1.5313239097595215. Validation Accuracy 0.4195545017719269
#
# Epoch 300, CIFAR-10 Batch 1:
# Loss: 1.5437250137329102. Validation Accuracy 0.41460397839546204
#
# Epoch 301, CIFAR-10 Batch 1:
# Loss: 1.5543431043624878. Validation Accuracy 0.4121287167072296
#
# Epoch 302, CIFAR-10 Batch 1:
# Loss: 1.5582900047302246. Validation Accuracy 0.408415824174881
#
# Epoch 303, CIFAR-10 Batch 1:
# Loss: 1.5341590642929077. Validation Accuracy 0.4183168113231659
#
# Epoch 304, CIFAR-10 Batch 1:
# Loss: 1.5027685165405273. Validation Accuracy 0.42574256658554077
#
# Epoch 305, CIFAR-10 Batch 1:
# Loss: 1.477638602256775. Validation Accuracy 0.4368811547756195
#
# Epoch 306, CIFAR-10 Batch 1:
# Loss: 1.4667295217514038. Validation Accuracy 0.43935641646385193
#
# Epoch 307, CIFAR-10 Batch 1:
# Loss: 1.463329792022705. Validation Accuracy 0.43935641646385193
#
# Epoch 308, CIFAR-10 Batch 1:
# Loss: 1.463582158088684. Validation Accuracy 0.4356435537338257
#
# Epoch 309, CIFAR-10 Batch 1:
# Loss: 1.4707814455032349. Validation Accuracy 0.4306930601596832
#
# Epoch 310, CIFAR-10 Batch 1:
# Loss: 1.4782474040985107. Validation Accuracy 0.4306930601596832
#
# Epoch 311, CIFAR-10 Batch 1:
# Loss: 1.4865798950195312. Validation Accuracy 0.4257425367832184
#
# Epoch 312, CIFAR-10 Batch 1:
# Loss: 1.493847131729126. Validation Accuracy 0.426980197429657
#
# Epoch 313, CIFAR-10 Batch 1:
# Loss: 1.50162935256958. Validation Accuracy 0.42945539951324463
#
# Epoch 314, CIFAR-10 Batch 1:
# Loss: 1.5067565441131592. Validation Accuracy 0.4282178282737732
#
# Epoch 315, CIFAR-10 Batch 1:
# Loss: 1.5083847045898438. Validation Accuracy 0.4282177686691284
#
# Epoch 316, CIFAR-10 Batch 1:
# Loss: 1.501083493232727. Validation Accuracy 0.426980197429657
#
# Epoch 317, CIFAR-10 Batch 1:
# Loss: 1.490646481513977. Validation Accuracy 0.4282178282737732
#
# Epoch 318, CIFAR-10 Batch 1:
# Loss: 1.4750525951385498. Validation Accuracy 0.4282178282737732
#
# Epoch 319, CIFAR-10 Batch 1:
# Loss: 1.4582185745239258. Validation Accuracy 0.4381188154220581
#
# Epoch 320, CIFAR-10 Batch 1:
# Loss: 1.4479399919509888. Validation Accuracy 0.44183164834976196
#
# Epoch 321, CIFAR-10 Batch 1:
# Loss: 1.4449548721313477. Validation Accuracy 0.44183167815208435
#
# Epoch 322, CIFAR-10 Batch 1:
# Loss: 1.443576693534851. Validation Accuracy 0.44306930899620056
#
# Epoch 323, CIFAR-10 Batch 1:
# Loss: 1.4421648979187012. Validation Accuracy 0.4455445408821106
#
# Epoch 324, CIFAR-10 Batch 1:
# Loss: 1.4403437376022339. Validation Accuracy 0.44306930899620056
#
# Epoch 325, CIFAR-10 Batch 1:
# Loss: 1.441157341003418. Validation Accuracy 0.44306930899620056
#
# Epoch 326, CIFAR-10 Batch 1:
# Loss: 1.4437286853790283. Validation Accuracy 0.4381188154220581
#
# Epoch 327, CIFAR-10 Batch 1:
# Loss: 1.4470620155334473. Validation Accuracy 0.4368811845779419
#
# Epoch 328, CIFAR-10 Batch 1:
# Loss: 1.4511916637420654. Validation Accuracy 0.4368811845779419
#
# Epoch 329, CIFAR-10 Batch 1:
# Loss: 1.4618042707443237. Validation Accuracy 0.4381187856197357
#
# Epoch 330, CIFAR-10 Batch 1:
# Loss: 1.471513032913208. Validation Accuracy 0.4368811249732971
#
# Epoch 331, CIFAR-10 Batch 1:
# Loss: 1.477266788482666. Validation Accuracy 0.43069303035736084
#
# Epoch 332, CIFAR-10 Batch 1:
# Loss: 1.4831310510635376. Validation Accuracy 0.43193069100379944
#
# Epoch 333, CIFAR-10 Batch 1:
# Loss: 1.490349531173706. Validation Accuracy 0.426980197429657
#
# Epoch 334, CIFAR-10 Batch 1:
# Loss: 1.495452642440796. Validation Accuracy 0.4269801378250122
#
# Epoch 335, CIFAR-10 Batch 1:
# Loss: 1.5009225606918335. Validation Accuracy 0.42202967405319214
#
# Epoch 336, CIFAR-10 Batch 1:
# Loss: 1.507148265838623. Validation Accuracy 0.4195544123649597
#
# Epoch 337, CIFAR-10 Batch 1:
# Loss: 1.511889934539795. Validation Accuracy 0.41584160923957825
#
# Epoch 338, CIFAR-10 Batch 1:
# Loss: 1.508034348487854. Validation Accuracy 0.4207920730113983
#
# Epoch 339, CIFAR-10 Batch 1:
# Loss: 1.502623438835144. Validation Accuracy 0.4220297038555145
#
# Epoch 340, CIFAR-10 Batch 1:
# Loss: 1.4982184171676636. Validation Accuracy 0.42450496554374695
#
# Epoch 341, CIFAR-10 Batch 1:
# Loss: 1.4840484857559204. Validation Accuracy 0.4294554591178894
#
# Epoch 342, CIFAR-10 Batch 1:
# Loss: 1.4502344131469727. Validation Accuracy 0.4443069100379944
#
# Epoch 343, CIFAR-10 Batch 1:
# Loss: 1.439192771911621. Validation Accuracy 0.4455445408821106
#
# Epoch 344, CIFAR-10 Batch 1:
# Loss: 1.4497569799423218. Validation Accuracy 0.4455445408821106
#
# Epoch 345, CIFAR-10 Batch 1:
# Loss: 1.4539082050323486. Validation Accuracy 0.4455445408821106
#
# Epoch 346, CIFAR-10 Batch 1:
# Loss: 1.4462345838546753. Validation Accuracy 0.4467821717262268
#
# Epoch 347, CIFAR-10 Batch 1:
# Loss: 1.4378979206085205. Validation Accuracy 0.448019802570343
#
# Epoch 348, CIFAR-10 Batch 1:
# Loss: 1.428404688835144. Validation Accuracy 0.448019802570343
#
# Epoch 349, CIFAR-10 Batch 1:
# Loss: 1.4296813011169434. Validation Accuracy 0.4430692791938782
#
# Epoch 350, CIFAR-10 Batch 1:
# Loss: 1.440805196762085. Validation Accuracy 0.4356435537338257
#
# Epoch 351, CIFAR-10 Batch 1:
# Loss: 1.444399356842041. Validation Accuracy 0.44059404730796814
#
# Epoch 352, CIFAR-10 Batch 1:
# Loss: 1.432330846786499. Validation Accuracy 0.44183167815208435
#
# Epoch 353, CIFAR-10 Batch 1:
# Loss: 1.4218714237213135. Validation Accuracy 0.4430692791938782
#
# Epoch 354, CIFAR-10 Batch 1:
# Loss: 1.4205105304718018. Validation Accuracy 0.45173266530036926
#
# Epoch 355, CIFAR-10 Batch 1:
# Loss: 1.4190895557403564. Validation Accuracy 0.44801977276802063
#
# Epoch 356, CIFAR-10 Batch 1:
# Loss: 1.4177223443984985. Validation Accuracy 0.44925740361213684
#
# Epoch 357, CIFAR-10 Batch 1:
# Loss: 1.4147030115127563. Validation Accuracy 0.448019802570343
#
# Epoch 358, CIFAR-10 Batch 1:
# Loss: 1.413801670074463. Validation Accuracy 0.448019802570343
#
# Epoch 359, CIFAR-10 Batch 1:
# Loss: 1.414428472518921. Validation Accuracy 0.44801974296569824
#
# Epoch 360, CIFAR-10 Batch 1:
# Loss: 1.4152252674102783. Validation Accuracy 0.4467821717262268
#
# Epoch 361, CIFAR-10 Batch 1:
# Loss: 1.4154884815216064. Validation Accuracy 0.448019802570343
#
# Epoch 362, CIFAR-10 Batch 1:
# Loss: 1.415490984916687. Validation Accuracy 0.4467821717262268
#
# Epoch 363, CIFAR-10 Batch 1:
# Loss: 1.4149982929229736. Validation Accuracy 0.44925740361213684
#
# Epoch 364, CIFAR-10 Batch 1:
# Loss: 1.413832187652588. Validation Accuracy 0.44925740361213684
#
# Epoch 365, CIFAR-10 Batch 1:
# Loss: 1.4103920459747314. Validation Accuracy 0.4517326354980469
#
# Epoch 366, CIFAR-10 Batch 1:
# Loss: 1.4076554775238037. Validation Accuracy 0.4517326354980469
#
# Epoch 367, CIFAR-10 Batch 1:
# Loss: 1.4045253992080688. Validation Accuracy 0.45173269510269165
#
# Epoch 368, CIFAR-10 Batch 1:
# Loss: 1.4019122123718262. Validation Accuracy 0.4542078971862793
#
# Epoch 369, CIFAR-10 Batch 1:
# Loss: 1.3994165658950806. Validation Accuracy 0.4554455280303955
#
# Epoch 370, CIFAR-10 Batch 1:
# Loss: 1.3984496593475342. Validation Accuracy 0.4554455280303955
#
# Epoch 371, CIFAR-10 Batch 1:
# Loss: 1.398632526397705. Validation Accuracy 0.4554455280303955
#
# Epoch 372, CIFAR-10 Batch 1:
# Loss: 1.398626446723938. Validation Accuracy 0.45544546842575073
#
# Epoch 373, CIFAR-10 Batch 1:
# Loss: 1.3987473249435425. Validation Accuracy 0.4566831588745117
#
# Epoch 374, CIFAR-10 Batch 1:
# Loss: 1.399613857269287. Validation Accuracy 0.45792078971862793
#
# Epoch 375, CIFAR-10 Batch 1:
# Loss: 1.4010365009307861. Validation Accuracy 0.4566831588745117
#
# Epoch 376, CIFAR-10 Batch 1:
# Loss: 1.40213942527771. Validation Accuracy 0.4566831588745117
#
# Epoch 377, CIFAR-10 Batch 1:
# Loss: 1.4030160903930664. Validation Accuracy 0.4566831588745117
#
# Epoch 378, CIFAR-10 Batch 1:
# Loss: 1.4037319421768188. Validation Accuracy 0.4566831588745117
#
# Epoch 379, CIFAR-10 Batch 1:
# Loss: 1.4048047065734863. Validation Accuracy 0.4554455280303955
#
# Epoch 380, CIFAR-10 Batch 1:
# Loss: 1.4059951305389404. Validation Accuracy 0.4542078971862793
#
# Epoch 381, CIFAR-10 Batch 1:
# Loss: 1.4065377712249756. Validation Accuracy 0.4542078971862793
#
# Epoch 382, CIFAR-10 Batch 1:
# Loss: 1.4072109460830688. Validation Accuracy 0.4542078971862793
#
# Epoch 383, CIFAR-10 Batch 1:
# Loss: 1.408218502998352. Validation Accuracy 0.4529702663421631
#
# Epoch 384, CIFAR-10 Batch 1:
# Loss: 1.4078140258789062. Validation Accuracy 0.4529702663421631
#
# Epoch 385, CIFAR-10 Batch 1:
# Loss: 1.4084974527359009. Validation Accuracy 0.4542078971862793
#
# Epoch 386, CIFAR-10 Batch 1:
# Loss: 1.4097009897232056. Validation Accuracy 0.4542078971862793
#
# Epoch 387, CIFAR-10 Batch 1:
# Loss: 1.4093306064605713. Validation Accuracy 0.4554455280303955
#
# Epoch 388, CIFAR-10 Batch 1:
# Loss: 1.4098623991012573. Validation Accuracy 0.4554455280303955
#
# Epoch 389, CIFAR-10 Batch 1:
# Loss: 1.4111720323562622. Validation Accuracy 0.4554455280303955
#
# Epoch 390, CIFAR-10 Batch 1:
# Loss: 1.4135735034942627. Validation Accuracy 0.4542078971862793
#
# Epoch 391, CIFAR-10 Batch 1:
# Loss: 1.4147425889968872. Validation Accuracy 0.4542078971862793
#
# Epoch 392, CIFAR-10 Batch 1:
# Loss: 1.4164707660675049. Validation Accuracy 0.4566831588745117
#
# Epoch 393, CIFAR-10 Batch 1:
# Loss: 1.4133081436157227. Validation Accuracy 0.45915842056274414
#
# Epoch 394, CIFAR-10 Batch 1:
# Loss: 1.4067054986953735. Validation Accuracy 0.46039605140686035
#
# Epoch 395, CIFAR-10 Batch 1:
# Loss: 1.4046046733856201. Validation Accuracy 0.4554455280303955
#
# Epoch 396, CIFAR-10 Batch 1:
# Loss: 1.4067137241363525. Validation Accuracy 0.4566831588745117
#
# Epoch 397, CIFAR-10 Batch 1:
# Loss: 1.4120988845825195. Validation Accuracy 0.4529702961444855
#
# Epoch 398, CIFAR-10 Batch 1:
# Loss: 1.412777066230774. Validation Accuracy 0.45049503445625305
#
# Epoch 399, CIFAR-10 Batch 1:
# Loss: 1.4092628955841064. Validation Accuracy 0.44925737380981445
#
# Epoch 400, CIFAR-10 Batch 1:
# Loss: 1.409461259841919. Validation Accuracy 0.45173266530036926
#
# Epoch 401, CIFAR-10 Batch 1:
# Loss: 1.4676378965377808. Validation Accuracy 0.4306930899620056
#
# Epoch 402, CIFAR-10 Batch 1:
# Loss: 1.608014702796936. Validation Accuracy 0.3836633265018463
#
# Epoch 403, CIFAR-10 Batch 1:
# Loss: 1.655600905418396. Validation Accuracy 0.37871289253234863
#
# Epoch 404, CIFAR-10 Batch 1:
# Loss: 1.5319156646728516. Validation Accuracy 0.4207920432090759
#
# Epoch 405, CIFAR-10 Batch 1:
# Loss: 1.4599956274032593. Validation Accuracy 0.44183164834976196
#
# Epoch 406, CIFAR-10 Batch 1:
# Loss: 1.4394901990890503. Validation Accuracy 0.4443069100379944
#
# Epoch 407, CIFAR-10 Batch 1:
# Loss: 1.4113984107971191. Validation Accuracy 0.4455445408821106
#
# Epoch 408, CIFAR-10 Batch 1:
# Loss: 1.395055890083313. Validation Accuracy 0.448019802570343
#
# Epoch 409, CIFAR-10 Batch 1:
# Loss: 1.390404462814331. Validation Accuracy 0.45173266530036926
#
# Epoch 410, CIFAR-10 Batch 1:
# Loss: 1.390350580215454. Validation Accuracy 0.45915842056274414
#
# Epoch 411, CIFAR-10 Batch 1:
# Loss: 1.3965431451797485. Validation Accuracy 0.45792078971862793
#
# Epoch 412, CIFAR-10 Batch 1:
# Loss: 1.408556342124939. Validation Accuracy 0.4529702663421631
#
# Epoch 413, CIFAR-10 Batch 1:
# Loss: 1.4424909353256226. Validation Accuracy 0.44801974296569824
#
# Epoch 414, CIFAR-10 Batch 1:
# Loss: 1.4605262279510498. Validation Accuracy 0.44059404730796814
#
# Epoch 415, CIFAR-10 Batch 1:
# Loss: 1.4449114799499512. Validation Accuracy 0.4455445408821106
#
# Epoch 416, CIFAR-10 Batch 1:
# Loss: 1.4126050472259521. Validation Accuracy 0.4529702663421631
#
# Epoch 417, CIFAR-10 Batch 1:
# Loss: 1.3904894590377808. Validation Accuracy 0.45792078971862793
#
# Epoch 418, CIFAR-10 Batch 1:
# Loss: 1.3858414888381958. Validation Accuracy 0.4554455280303955
#
# Epoch 419, CIFAR-10 Batch 1:
# Loss: 1.3843258619308472. Validation Accuracy 0.4529702663421631
#
# Epoch 420, CIFAR-10 Batch 1:
# Loss: 1.3782975673675537. Validation Accuracy 0.45792078971862793
#
# Epoch 421, CIFAR-10 Batch 1:
# Loss: 1.3727221488952637. Validation Accuracy 0.46039605140686035
#
# Epoch 422, CIFAR-10 Batch 1:
# Loss: 1.3727912902832031. Validation Accuracy 0.462871253490448
#
# Epoch 423, CIFAR-10 Batch 1:
# Loss: 1.373105525970459. Validation Accuracy 0.462871253490448
#
# Epoch 424, CIFAR-10 Batch 1:
# Loss: 1.3711787462234497. Validation Accuracy 0.462871253490448
#
# Epoch 425, CIFAR-10 Batch 1:
# Loss: 1.3687026500701904. Validation Accuracy 0.462871253490448
#
# Epoch 426, CIFAR-10 Batch 1:
# Loss: 1.3670425415039062. Validation Accuracy 0.462871253490448
#
# Epoch 427, CIFAR-10 Batch 1:
# Loss: 1.3665627241134644. Validation Accuracy 0.4616336226463318
#
# Epoch 428, CIFAR-10 Batch 1:
# Loss: 1.3666337728500366. Validation Accuracy 0.4616336226463318
#
# Epoch 429, CIFAR-10 Batch 1:
# Loss: 1.366949439048767. Validation Accuracy 0.45792078971862793
#
# Epoch 430, CIFAR-10 Batch 1:
# Loss: 1.3671513795852661. Validation Accuracy 0.4554455280303955
#
# Epoch 431, CIFAR-10 Batch 1:
# Loss: 1.3673148155212402. Validation Accuracy 0.4554455280303955
#
# Epoch 432, CIFAR-10 Batch 1:
# Loss: 1.367509365081787. Validation Accuracy 0.4554455280303955
#
# Epoch 433, CIFAR-10 Batch 1:
# Loss: 1.3674553632736206. Validation Accuracy 0.45915842056274414
#
# Epoch 434, CIFAR-10 Batch 1:
# Loss: 1.3672754764556885. Validation Accuracy 0.45915842056274414
#
# Epoch 435, CIFAR-10 Batch 1:
# Loss: 1.3666884899139404. Validation Accuracy 0.45915836095809937
#
# Epoch 436, CIFAR-10 Batch 1:
# Loss: 1.3662117719650269. Validation Accuracy 0.46039605140686035
#
# Epoch 437, CIFAR-10 Batch 1:
# Loss: 1.365468144416809. Validation Accuracy 0.4603959918022156
#
# Epoch 438, CIFAR-10 Batch 1:
# Loss: 1.364364743232727. Validation Accuracy 0.45915842056274414
#
# Epoch 439, CIFAR-10 Batch 1:
# Loss: 1.363052248954773. Validation Accuracy 0.4603959918022156
#
# Epoch 440, CIFAR-10 Batch 1:
# Loss: 1.3614006042480469. Validation Accuracy 0.4616336226463318
#
# Epoch 441, CIFAR-10 Batch 1:
# Loss: 1.3585015535354614. Validation Accuracy 0.4616336226463318

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
